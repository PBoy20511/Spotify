# %%
import json
import random
import warnings

import spotipy
import spotipy.util as util
import requests
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
from tqdm import tqdm
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
username = 'virginiakm1988'
scope = 'user-top-read'#'user-library-read' #user-read-currently-playing

# %%
token = util.prompt_for_user_token(username,scope,
                          client_id='626842ec9a694c66b24055c07e888ab5',
                          client_secret='a5bf49eec50f48559c3efd38c7ad6691',
                          # 注意需要在自己的web app中添加redirect url
                          redirect_uri='http://localhost/5000')
# Out:
#             User authentication requires interaction with your
#             web browser. Once you enter your credentials and
#             give authorization, you will be redirected to
#             a url.  Paste that url you were directed to to
#             complete the authorization.
#
#
# Opened https://accounts.spotify.com/authorize?client_id=626842ec9a694c66b24055c07e888ab5&response_type=code&redirect_uri=http%3A%2F%2Flocalhost%2F5000&scope=user-top-read in your browser
#
#
# Enter the URL you were redirected to: http://localhost/5000?code=AQBrsAYUJElz6UVqH2T4e5tNm8Q3KDxoKDaobV9ripfMLysmUaDm_QpKx9JWDDWTP0PBA60hCCqrRpPgm0DMxiVwUEXxu9UN_GmK6cQWRMIZpHn27YnY4i2CzjtlVTtGd3j3bDCOcuRrnrNX7n7arpmSzCAfSFeeZ159pfiarwT3f5pYfiRZhI5U9wva8JbBX5JWrqHC7OTPSA

# %%
#token = 'BQBczbrrfVFMG9OjSmFmYbsbQoVRBXhZtudpCi1DQCL97qbwvumglB2Pj_Yci2v4sXbyQMK42dduSvj1Ob36vYP2exDKOYhpt0w0P7GUE4wbLsNER0gr0PyA3wh17lWIUrgUpBmxADpx0QKvprpox_pEJs0'
#token='BQDXAxeBrvQbTt0WNryO-2LCShi3ty0zGpKhLyyUvlXwamfNrVA0_q2Z0-YdzziQ0giwa--JGW7OUZWuR2SQ_O00_ZnBGXk8DY9BuPrKft-3NS24j8GkVkVhQx5r4iqankz9L0I-7ggtYnbUh0-g67rGR1mBNg'
headers = {"Authorization": "Bearer {}".format(token)}

# %%
headers
# Out:
# {'Authorization': 'Bearer BQDcbOKqmKVDaoITO2GfEmwoitpAcNSauR50oOI2xHpo42PpJ7resEM7glIej-UW_GnZEuY19QRkcPnxodGrX0FydDNthKVslJlv-ZiVSOhL7Nu5si9R-m_37Gh6NqfiRPo-dOSm96bbLDf_AcdzPi9TzdA'}

# %%
#responses = requests.get("https://api.spotify.com/v1/me/tracks?offset=0&limit=50", headers=headers)
responses = requests.get("https://api.spotify.com/v1/me/top/tracks?time_range=medium_term&limit=100&offset=5", headers=headers)
myjson_data = json.loads(responses.text)
len(myjson_data["items"])
for i in myjson_data["items"]:
    #print(json.dumps(i, indent=4))
    #break
    print(i["name"], i["href"])

#uri and name of the song
# Out:
# Imagine - Remastered https://api.spotify.com/v1/tracks/7pKfPomDEeI4TPT6EOYjn9
# Fuck it I love you https://api.spotify.com/v1/tracks/7MtVPRGtZl6rPjMfLoI3Lh
# Venice Bitch https://api.spotify.com/v1/tracks/3hwQhakFwm9soLEBnSDH17
# Mariners Apartment Complex https://api.spotify.com/v1/tracks/6OG05bPAwUuV3OMvy2Vy1P
# Happiness is a butterfly https://api.spotify.com/v1/tracks/3lG6OtGDsYAOALxEmubQQm
# Bartender https://api.spotify.com/v1/tracks/5USsRaiqL1RNKRm1fTJ3JM
# Cinnamon Girl https://api.spotify.com/v1/tracks/2mdEsXPu8ZmkHRRtAdC09e
# The Next Best American Record https://api.spotify.com/v1/tracks/7vRfxLcDDwgYW2WTrtEgUV
# Piano Sonata No. 8 in C Minor, Op. 13 "Pathétique": I. Grave - Allegro di molto e con brio https://api.spotify.com/v1/tracks/7CVSCdKA6WxNirbkKvefqf
# Don't Dream It's Over https://api.spotify.com/v1/tracks/7G7tgVYORlDuVprcYHuFJh
# Make You Feel My Love https://api.spotify.com/v1/tracks/0mqTcM8kuu2IYPotMt7AzS
# ...

# %% [markdown]
# ### Get currently playing 需要request不同的token

# %%
scope = "user-read-currently-playing"
token =util.prompt_for_user_token(username,scope,
                          client_id='626842ec9a694c66b24055c07e888ab5',
                          client_secret='a5bf49eec50f48559c3efd38c7ad6691',
                          # 注意需要在自己的web app中添加redirect url
                          redirect_uri='http://localhost/5000')

# %%
#token=to#'BQBh1H0GXlykz5dvSoVz6gsYHmXd_3-Za3NeO_F10zdSx5ewYHG4PIZ0rj8pm_q3Cf3BVs3PLbcmz4KtOOxaN-uxS5iFa5q16S0oxeTwu0t0b_cG1FpIAUBs5xQNgP2pCvQE0NFw091nvulUzBdoBVyR'
headers = {"Authorization": "Bearer {}".format(token)}
headers
# Out:
# {'Authorization': 'Bearer BQCNllwKqneGUj4zZwREIDenk4W1C5ZABr7UldjCUzTvZy0bf2a1XNcYAwYjoLaZ5vgBmiTs-GHcrekpRkIKZk1S4NlDxmXUpErCZ24tEQwecT675PkZ_Pc258LN8A39n7xStSU1eedTR-JgGRFtnV6R'}

# %%
responses = requests.get("https://api.spotify.com/v1/me/player/currently-playing",headers=headers)
headers

myjson_data = json.loads(responses.text)
myjson_data
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-14-f16154f85600> in <module>()
#       2 headers
#       3
# ----> 4 myjson_data = json.loads(responses.text)
#       5 myjson_data
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     317             parse_int is None and parse_float is None and
#     318             parse_constant is None and object_pairs_hook is None and not kw):
# --> 319         return _default_decoder.decode(s)
#     320     if cls is None:
#     321         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ...

# %%
print(myjson_data.get('items')[1]['href'])

artist_name = myjson_data.get('items')[1]['artists'][0]['name']
song_name = myjson_data.get('items')[1]['name']
song_ids = myjson_data.get('items')[1]["id"]
song_attributes = requests.get('https://api.spotify.com/v1/audio-features/'+song_ids, headers=headers).text
#myjson_data.get('items')[1]
# Out:
# https://api.spotify.com/v1/tracks/7MtVPRGtZl6rPjMfLoI3Lh

# %%
song_attributes
# Out:
# '{\n  "danceability" : 0.532,\n  "energy" : 0.452,\n  "key" : 9,\n  "loudness" : -10.654,\n  "mode" : 0,\n  "speechiness" : 0.0430,\n  "acousticness" : 0.892,\n  "instrumentalness" : 0.00113,\n  "liveness" : 0.127,\n  "valence" : 0.203,\n  "tempo" : 129.895,\n  "type" : "audio_features",\n  "id" : "7MtVPRGtZl6rPjMfLoI3Lh",\n  "uri" : "spotify:track:7MtVPRGtZl6rPjMfLoI3Lh",\n  "track_href" : "https://api.spotify.com/v1/tracks/7MtVPRGtZl6rPjMfLoI3Lh",\n  "analysis_url" : "https://api.spotify.com/v1/audio-analysis/7MtVPRGtZl6rPjMfLoI3Lh",\n  "duration_ms" : 218288,\n  "time_signature" : 4\n}'

# %%
my_songs_attributes = list()
my_songs_names = list()

for item in myjson_data.get('items'):
    print(item['name'])
    song_attribute=dict()
    artist_name = item['artists'][0]['name']
    song_name = item['name']
    song_ids = item["id"]
    audio_features = requests.get('https://api.spotify.com/v1/audio-features/'+song_ids, headers=headers).text
    song_attribute['artist_name']=(artist_name)
    song_attribute['song_name']=(song_name)
    song_attribute['song_ids']=(song_ids)
    song_attribute['audio_features']=(audio_features)
 
    my_songs_attributes.append(song_attribute)
    my_songs_names.append(song_name)
# Out:
# Imagine - Remastered
# Fuck it I love you
# Venice Bitch
# Mariners Apartment Complex
# Happiness is a butterfly
# Bartender
# Cinnamon Girl
# The Next Best American Record
# Piano Sonata No. 8 in C Minor, Op. 13 "Pathétique": I. Grave - Allegro di molto e con brio
# Don't Dream It's Over
# Make You Feel My Love
# Someone in the Dark
# Hotel California - 2013 Remaster
# Eleanor Rigby - Remastered 2009
# Liberian Girl - 2012 Remastered Version
# Space Oddity - 2015 Remaster
# Love Never Felt So Good (Original Version)
# California
# The Long And Winding Road - Remastered 2009
# Piano Sonata No. 8 in C Minor, Op. 13 "Pathétique": III. Rondo. Allegro
# Morphine
# Welcome To The Jungle
# Starman - 2012 Remaster
# Piano Sonata No. 8 in C Minor, Op. 13 "Pathétique": II. Adagio cantabile
# Sweet Dreams (Are Made of This) - Remastered
# The Lady in My Life
# Do You Know Where Your Children Are (Original Version)
# Stairway to Heaven - Remaster
# Million Dollar Man
# ...

# %%
my_songs_attributes
# Out:
# [{'artist_name': 'John Lennon',
#   'audio_features': '{\n  "danceability" : 0.547,\n  "energy" : 0.257,\n  "key" : 0,\n  "loudness" : -12.358,\n  "mode" : 1,\n  "speechiness" : 0.0252,\n  "acousticness" : 0.907,\n  "instrumentalness" : 0.183,\n  "liveness" : 0.0935,\n  "valence" : 0.169,\n  "tempo" : 75.752,\n  "type" : "audio_features",\n  "id" : "7pKfPomDEeI4TPT6EOYjn9",\n  "uri" : "spotify:track:7pKfPomDEeI4TPT6EOYjn9",\n  "track_href" : "https://api.spotify.com/v1/tracks/7pKfPomDEeI4TPT6EOYjn9",\n  "analysis_url" : "https://api.spotify.com/v1/audio-analysis/7pKfPomDEeI4TPT6EOYjn9",\n  "duration_ms" : 187867,\n  "time_signature" : 4\n}',
#   'song_ids': '7pKfPomDEeI4TPT6EOYjn9',
#   'song_name': 'Imagine - Remastered'},
#  {'artist_name': 'Lana Del Rey',
# ...

# %%
df = pd.DataFrame(myjson_data)

# %%
df[items]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4c82bf9b12de> in <module>()
# ----> 1 df[items]
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### get a user's rescently played track

# %%
scope = "user-read-recently-played"
util.prompt_for_user_token(username,scope,
                          client_id='626842ec9a694c66b24055c07e888ab5',
                          client_secret='a5bf49eec50f48559c3efd38c7ad6691',
                          # 注意需要在自己的web app中添加redirect url
                          redirect_uri='http://localhost/5000')
# Out:
#             User authentication requires interaction with your
#             web browser. Once you enter your credentials and
#             give authorization, you will be redirected to
#             a url.  Paste that url you were directed to to
#             complete the authorization.
#
#
# Opened https://accounts.spotify.com/authorize?response_type=code&redirect_uri=http%3A%2F%2Flocalhost%2F5000&scope=user-read-recently-played&client_id=626842ec9a694c66b24055c07e888ab5 in your browser
#
#
# Enter the URL you were redirected to: http://localhost/5000?code=AQAguyIJ4OR-OA0sLeyLIO0sFZLMSuRURuxJZzV_6I_FAZctzk9BFWc2K5BlAQduEabgM3c1_poTve5ChsDnXP1xSu5gedpDmujJ-ia5IzGSGBO95fazkW318RLNM5nqMZMVWBHwkSm07GaUaUBYhCEkbwrpWQ-elKy5YlFGR9QRhCEbaCXp5zu5mMATehPaXk_RXRZ1_sMuYrH6T8AWVKTzGkb6Xg
# 'BQC31f0GNd6z7sNAoAgMCbUC_TH3VavY8H0cSsvVv5wYFaYboTOK76xfgR0SsmDD1FJTxa0pWhZqRHCWlDQhmp6TcGzbOuJPYnYAloeNO20p70ptFBi8Q6KchP7rI4yjZQi9CJshmd8h207o_J1-xv7b'

# %%
token='BQC31f0GNd6z7sNAoAgMCbUC_TH3VavY8H0cSsvVv5wYFaYboTOK76xfgR0SsmDD1FJTxa0pWhZqRHCWlDQhmp6TcGzbOuJPYnYAloeNO20p70ptFBi8Q6KchP7rI4yjZQi9CJshmd8h207o_J1-xv7b'
headers = {"Authorization": "Bearer {}".format(token)}
headers
# Out:
# {'Authorization': 'Bearer BQC31f0GNd6z7sNAoAgMCbUC_TH3VavY8H0cSsvVv5wYFaYboTOK76xfgR0SsmDD1FJTxa0pWhZqRHCWlDQhmp6TcGzbOuJPYnYAloeNO20p70ptFBi8Q6KchP7rI4yjZQi9CJshmd8h207o_J1-xv7b'}

# %%
responses = requests.get("https://api.spotify.com/v1/me/player/recently-played",headers=headers)
headers

myjson_data = json.loads(responses.text)
myjson_data
# Out:
# {'cursors': {'after': '1575695442215', 'before': '1574982045601'},
#  'href': 'https://api.spotify.com/v1/me/player/recently-played',
#  'items': [{'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXaTIN6XNquoW'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXaTIN6XNquoW',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXaTIN6XNquoW'},
#    'played_at': '2019-12-07T05:10:42.215Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3fMbdgg4jU18AjLCKBhRSm'},
#        'href': 'https://api.spotify.com/v1/artists/3fMbdgg4jU18AjLCKBhRSm',
#        'id': '3fMbdgg4jU18AjLCKBhRSm',
#        'name': 'Michael Jackson',
#        'type': 'artist',
#        'uri': 'spotify:artist:3fMbdgg4jU18AjLCKBhRSm'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
# ...

# %%
user-top-read
